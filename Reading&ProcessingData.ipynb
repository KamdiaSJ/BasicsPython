# %%
import pandas as pd

# %%
df = pd.read_excel('https://bit.ly/autompg-xlsx')
df
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0      US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0      US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0      US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0      US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0      US
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0      US
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0      US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0      US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0      US
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#               mpg         cyl       displ          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel          yr
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
s=df['yr']

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# 75.9795918367347

# %%
s.max()
# Out:
# 82.0

# %%
df['yr']+1900
# Out:
# 0      1970.0
# 1      1970.0
# 2      1970.0
# 3      1970.0
# 4      1970.0
#         ...
# 387    1982.0
# 388    1982.0
# 389    1982.0
# 390    1982.0
# 391    1982.0
# Name: yr, Length: 392, dtype: float64

# %%
year = df['yr']+1900

# %%
year
# Out:
# 0      1970.0
# 1      1970.0
# 2      1970.0
# 3      1970.0
# 4      1970.0
#         ...
# 387    1982.0
# 388    1982.0
# 389    1982.0
# 390    1982.0
# 391    1982.0
# Name: yr, Length: 392, dtype: float64

# %%
df['year_py']=df['yr']+1900

# %%
df
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0      US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0      US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0      US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0      US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0      US
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0      US
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0      US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0      US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0      US
#
#                           name  year_py
# 0    chevrolet chevelle malibu   1970.0
# 1            buick skylark 320   1970.0
# 2           plymouth satellite   1970.0
# 3                amc rebel sst   1970.0
# 4                  ford torino   1970.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mpg      392 non-null    float64
#  1   cyl      392 non-null    float64
#  2   displ    392 non-null    float64
#  3   hp       392 non-null    float64
#  4   weight   392 non-null    float64
#  5   accel    392 non-null    float64
#  6   yr       392 non-null    float64
#  7   origin   392 non-null    object
#  8   name     392 non-null    object
#  9   year_py  392 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 30.8+ KB

# %%
df['mpg'].hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df['mpg'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df.plot?
# Out:
# Signature:      df.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x7f72f6bb4e20>
# File:           /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/pandas/plotting/_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
# ...

# %%
df.plot.scatter(x='mpg',y='hp')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='hp'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0      US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0      US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0      US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0      US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0      US
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0      US
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0      US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0      US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0      US
#
#                           name  year_py
# 0    chevrolet chevelle malibu   1970.0
# 1            buick skylark 320   1970.0
# 2           plymouth satellite   1970.0
# 3                amc rebel sst   1970.0
# 4                  ford torino   1970.0
# ...

# %%
#loc will access any row for example I want values from row 300 however you need to use [] square brackets
# loc is operates via axis of rows and extracts data of columns in that row

df.loc[300]
# Out:
# mpg                        34.5
# cyl                         4.0
# displ                     105.0
# hp                         70.0
# weight                   2150.0
# accel                      14.9
# yr                         79.0
# origin                       US
# name       plymouth horizon tc3
# year_py                  1979.0
# Name: 300, dtype: object

# %%
# to get a single value of column hp from row label 300

df.loc[300,'hp']
# Out:
# 70.0

# %%
# you can also use the loc command with the assignment operator "=" to reassign the value

df.loc[300,'hp'] = 7000

# %%
df.loc[300]
# Out:
# mpg                        34.5
# cyl                         4.0
# displ                     105.0
# hp                       7000.0
# weight                   2150.0
# accel                      14.9
# yr                         79.0
# origin                       US
# name       plymouth horizon tc3
# year_py                  1979.0
# Name: 300, dtype: object

# %%
#you can use df. to do comparision such as == can do boolean case

df['origin'] == 'US'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 387     True
# 388    False
# 389     True
# 390     True
# 391     True
# Name: origin, Length: 392, dtype: bool

# %%
#now if we use the loc function on this output we can filter the number of rows which have US origin

df.loc[df['origin']=='US']
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0     US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0     US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0     US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0     US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0     US
# ..    ...  ...    ...    ...     ...    ...   ...    ...
# 386  27.0  4.0  151.0   90.0  2950.0   17.3  82.0     US
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0     US
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0     US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0     US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0     US
#
#                           name  year_py
# 0    chevrolet chevelle malibu   1970.0
# 1            buick skylark 320   1970.0
# 2           plymouth satellite   1970.0
# 3                amc rebel sst   1970.0
# 4                  ford torino   1970.0
# ...

# %%
#doing same for europe
df.loc[df['origin']=='Europe']
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 19   26.0  4.0   97.0   46.0  1835.0   20.5  70.0  Europe
# 20   25.0  4.0  110.0   87.0  2672.0   17.5  70.0  Europe
# 21   24.0  4.0  107.0   90.0  2430.0   14.5  70.0  Europe
# 22   25.0  4.0  104.0   95.0  2375.0   17.5  70.0  Europe
# 23   26.0  4.0  121.0  113.0  2234.0   12.5  70.0  Europe
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 349  33.0  4.0  105.0   74.0  2190.0   14.2  81.0  Europe
# 354  28.1  4.0  141.0   80.0  3230.0   20.4  81.0  Europe
# 355  30.7  6.0  145.0   76.0  3160.0   19.6  81.0  Europe
# 369  36.0  4.0  105.0   74.0  1980.0   15.3  82.0  Europe
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
#
#                              name  year_py
# 19   volkswagen 1131 deluxe sedan   1970.0
# 20                    peugeot 504   1970.0
# 21                    audi 100 ls   1970.0
# 22                       saab 99e   1970.0
# 23                       bmw 2002   1970.0
# ...

# %%
# we can assign the same to variable europe and USA for future | your dataframe df stays the same however
# multiple objects are created in python

europe = df.loc[df['origin']=='Europe']

USA = df.loc[df['origin']=='US']

# %%
df
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0      US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0      US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0      US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0      US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0      US
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0      US
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0      US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0      US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0      US
#
#                           name  year_py
# 0    chevrolet chevelle malibu   1970.0
# 1            buick skylark 320   1970.0
# 2           plymouth satellite   1970.0
# 3                amc rebel sst   1970.0
# 4                  ford torino   1970.0
# ...

# %%
europe
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr  origin  \
# 19   26.0  4.0   97.0   46.0  1835.0   20.5  70.0  Europe
# 20   25.0  4.0  110.0   87.0  2672.0   17.5  70.0  Europe
# 21   24.0  4.0  107.0   90.0  2430.0   14.5  70.0  Europe
# 22   25.0  4.0  104.0   95.0  2375.0   17.5  70.0  Europe
# 23   26.0  4.0  121.0  113.0  2234.0   12.5  70.0  Europe
# ..    ...  ...    ...    ...     ...    ...   ...     ...
# 349  33.0  4.0  105.0   74.0  2190.0   14.2  81.0  Europe
# 354  28.1  4.0  141.0   80.0  3230.0   20.4  81.0  Europe
# 355  30.7  6.0  145.0   76.0  3160.0   19.6  81.0  Europe
# 369  36.0  4.0  105.0   74.0  1980.0   15.3  82.0  Europe
# 388  44.0  4.0   97.0   52.0  2130.0   24.6  82.0  Europe
#
#                              name  year_py
# 19   volkswagen 1131 deluxe sedan   1970.0
# 20                    peugeot 504   1970.0
# 21                    audi 100 ls   1970.0
# 22                       saab 99e   1970.0
# 23                       bmw 2002   1970.0
# ...

# %%
USA
# Out:
#       mpg  cyl  displ     hp  weight  accel    yr origin  \
# 0    18.0  8.0  307.0  130.0  3504.0   12.0  70.0     US
# 1    15.0  8.0  350.0  165.0  3693.0   11.5  70.0     US
# 2    18.0  8.0  318.0  150.0  3436.0   11.0  70.0     US
# 3    16.0  8.0  304.0  150.0  3433.0   12.0  70.0     US
# 4    17.0  8.0  302.0  140.0  3449.0   10.5  70.0     US
# ..    ...  ...    ...    ...     ...    ...   ...    ...
# 386  27.0  4.0  151.0   90.0  2950.0   17.3  82.0     US
# 387  27.0  4.0  140.0   86.0  2790.0   15.6  82.0     US
# 389  32.0  4.0  135.0   84.0  2295.0   11.6  82.0     US
# 390  28.0  4.0  120.0   79.0  2625.0   18.6  82.0     US
# 391  31.0  4.0  119.0   82.0  2720.0   19.4  82.0     US
#
#                           name  year_py
# 0    chevrolet chevelle malibu   1970.0
# 1            buick skylark 320   1970.0
# 2           plymouth satellite   1970.0
# 3                amc rebel sst   1970.0
# 4                  ford torino   1970.0
# ...

# %%
europe['mpg'].mean()
# Out:
# 27.602941176470587

# %%
USA['mpg'].mean()
# Out:
# 20.033469387755098

# %%
df['mpg'].mean()
# Out:
# 23.44591836734694

# %%
#you can do all the above calculation of mean in a single step as well however you won't be able to see the data
# because that is a limitation with pandas and jupyter nb as well

df.loc[df['origin']=='Europe', 'mpg'].mean()
# Out:
# 27.602941176470587

# %%
df.loc[df['origin']=='US', 'mpg'].mean()
# Out:
# 20.033469387755098

# %%
# #PIVOT TABLE
# #in pandas we can create a pivot table just as easily in excel
# the index means the rows, columns are things that you want to see at the top of dataframe
# values are the values and the aggfunc is how you want to aggregate

df.pivot_table?
# Out:
# Signature:
# df.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc='mean',
#     fill_value=None,
#     margins=False,
#     dropna=True,
#     margins_name='All',
#     observed=False,
#     sort=True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# values : column to aggregate, optional
# index : column, Grouper, array, or list of the previous
#     If an array is passed, it must be the same length as the data. The
#     list can contain any of the other types (except list).
#     Keys to group by on the pivot table index.  If an array is passed,
#     it is being used as the same manner as column values.
# columns : column, Grouper, array, or list of the previous
#     If an array is passed, it must be the same length as the data. The
# ...

# %%
df.pivot_table(
    index='year_py',
    columns='origin',
    values='mpg',
    aggfunc='mean')
# Out:
# origin        Asia   Europe         US
# year_py
# 1970.0   25.500000  25.2000  15.272727
# 1971.0   29.500000  28.7500  17.736842
# 1972.0   24.200000  22.0000  16.277778
# 1973.0   20.000000  24.0000  15.034483
# 1974.0   29.333333  27.0000  18.142857
# 1975.0   27.500000  24.5000  17.550000
# 1976.0   28.000000  24.2500  19.431818
# 1977.0   27.416667  29.2500  20.722222
# 1978.0   29.687500  24.9500  21.772727
# 1979.0   32.950000  30.4500  23.478261
# 1980.0   35.400000  36.8375  26.300000
# 1981.0   32.958333  30.6000  27.530769
# 1982.0   34.888889  40.0000  29.789474

# %%
#to create a visual plot line for the same you can just add .plot.line()
# NOTE: plot function would always treat index as x
df.pivot_table(
    index='year_py',
    columns='origin',
    values='mpg',
    aggfunc='mean').plot.line()
# Out:
# <AxesSubplot:xlabel='year_py'>
